# %%
import numpy as np
import seaborn as sns

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist() # Notice that it is actually calling matplotlib under the hood.

# %%
df1['A'].hist(bins=30)

# %%
df1['A'].plot(kind='hist', bins=30)

# %%
df2.plot.area()

# %%
df2.plot.area(alpha=0.4)

# %%
df2.plot.bar(stacked=True)

# %%
df1['A'].plot.hist(bins=50)

# %%
df1.plot.line(y='B')

# %%
df1.plot.line(y='B', figsize=(12,3))

# %%
df1.plot.line(y='B', figsize=(12,3), lw=1) # lw stands for line width

# %%
df1.plot.line(y='B', figsize=(15,6), lw=0.8)

# %%
df1.plot.scatter(x='A', y='B')

# %%
df1.plot.scatter(x='A', y='B', figsize=(15,8), c='C') # we are setting the color c based off of another column, C in this case

# %%
df1.plot.scatter(x='A', y='B', figsize=(15,8), s=df1['C']*100) # according to their size

# %%
df2.plot.box(figsize=(10,6))

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])
df.head()
# Out:
#           a         b
# 0 -1.291797 -1.314663
# 1 -1.411493 -1.627743
# 2  0.255971  0.181761
# 3 -0.022289 -0.570488
# 4  0.163279 -0.269072

# %%
df.plot.hexbin(x='a', y='b', figsize=(12,9), gridsize=30)

# %%
df.plot.hexbin(x='a', y='b', figsize=(12,9), gridsize=30, cmap='coolwarm')

# %%
df2['a'].plot.kde()
